# %% [markdown]
# At a high level, the Langchain agent will:
#
# - Fetch the available tables from the database
# - Decide which tables are relevant to the question
# - Fetch the schemas for the relevant tables
# - Generate a query based on the question and information from the schemas
# - Double-check the query for common mistakes using an LLM
# - Execute the query and return the results
# - Correct mistakes surfaced by the database engine until the query is successful
# - Formulate a response based on the results

# %%
import os
from dotenv import load_dotenv
load_dotenv()
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")
## Langsmith Tracking
os.environ["LANGCHAIN_API_KEY"] = os.getenv("LANGCHAIN_API_KEY")
os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_PROJECT"] = os.getenv("LANGCHAIN_PROJECT")

# %%
from langchain.chat_models import init_chat_model
from langchain_community.utilities import SQLDatabase
from langchain_community.agent_toolkits import SQLDatabaseToolkit
import requests

# %%
llm = init_chat_model("openai:gpt-4.1")
llm
# Out:
# ChatOpenAI(client=<openai.resources.chat.completions.completions.Completions object at 0x129c396d0>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x129c3a0d0>, root_client=<openai.OpenAI object at 0x129c38410>, root_async_client=<openai.AsyncOpenAI object at 0x129c39810>, model_name='gpt-4.1', model_kwargs={}, openai_api_key=SecretStr('**********'))

# %%
# Try to connect to the database with different paths
import os

# Define possible database paths
possible_db_paths = [
    # 'boiler_data_all_sheets.db',  # Current directory
    '../boiler_data_all_sheets.db',  # Parent directory
    os.path.join('..', 'boiler_data_all_sheets.db'),  # Alternative parent directory syntax
    os.path.abspath('boiler_data_all_sheets.db'),  # Absolute path current dir
    os.path.abspath(os.path.join('..', 'boiler_data_all_sheets.db'))  # Absolute path parent dir
]

# Try each path
for db_path in possible_db_paths:
    if os.path.exists(db_path):
        print(f"Found database at: {db_path}")
        try:
            # Try to connect with SQLDatabase
            db = SQLDatabase.from_uri(f"sqlite:///{db_path}")
            tables = db.get_usable_table_names()
            
            print(f"Dialect: {db.dialect}")
            if tables:
                print("Available tables:")
                for table in tables:
                    print(f"- {table}")
                # If we found tables, break the loop
                break
            else:
                print("No tables found in this database.")
        except Exception as e:
            print(f"Error connecting to database at {db_path}: {str(e)}")
    else:
        print(f"Database file not found at: {db_path}")
# Out:
# Found database at: ../boiler_data_all_sheets.db
# Dialect: sqlite
# Available tables:
# - boiler_bol2
# - boiler_bolr_1
# - boiler_bolr_3
# - boiler_data
# - monthly_stats
# - weekly_stats

# %%
print(f'Sample output: {db.run("SELECT * FROM boiler_bolr_1 LIMIT 1;")}')
# Out:
# Sample output: [('2024-04-01 00:00:00.000000', 0.0, 1489, 1300.6261740742507, 188.37382592574932, 0.1922091235263967, 1300.4339649507242, 0.0, 885, 24, 0, 0, 0, 0, 10.17, 2.7, 2.2, 127.5, 119.4, 29.2, 82.52, 155.8, 101.75, 26.4375, 6.779, 29.30000000000001, 23.99, 10.17, 36.54, 3902, 41.538768388099996, 3.0232189383, 0.47961000000000004, 1.8121200000000002, 6.436282673600006, 2.45, 17.8, 5.9139146567718, 192.487, 247.2934, 34.3801, 27.9036, 33.2, 123.45, 13.486085343228199, 50, 60, 10, 6.738, 16.738, 0.0016738, 5.59, 1.86, 900, 123.45, 16.0, 0.2999940001199976, 0.022108138699871965, 5.611462062246399, 39.20112157808004, 7.811218127575447, 8.071383427489108, 4.480424526894262, 1.6279623590466428, 4.324986573687069, 0.17973944877282327, 0.007588300895165009, 1.2661548255253716, 0.42280797339825726, 1.6889627989236289, 0.1606019911360385, 0.41509092952010984, 0.5756929206561483, 0.65, 13.53535692887574, 86.46464307112426, 0.13838592600048844, 0.09953832839195971, 0.5, 85.7267188167318, 541.125, 1489.0, 885, 885, 24.0, 0.0, 6675.0, 489.7, 74.75, 74.28509787000354, 808.8286549040403, 6691.0, 155.8, 101.75, 100.76295453653944, 158.6358882669904, 0.15, 0.84, 0.126, 10750, 1297.0346795237008, 1307.4109569598904, 1058.0, 380.0, 6.0, 2024, 4, 14, 1, 0, 'Bolr 1')]

# %% [markdown]
# ### Tools for database interactions
#
# langchain-community implements some built-in tools for interacting with our SQLDatabase, including tools for listing tables, reading table schemas, and checking and running queries

# %%
from langchain_community.agent_toolkits import SQLDatabaseToolkit

toolkit = SQLDatabaseToolkit(db=db, llm=llm)

tools = toolkit.get_tools()

for tool in tools:
    print(f"{tool.name}: {tool.description}\n")
# Out:
# sql_db_query: Input to this tool is a detailed and correct SQL query, output is a result from the database. If the query is not correct, an error message will be returned. If an error is returned, rewrite the query, check the query, and try again. If you encounter an issue with Unknown column 'xxxx' in 'field list', use sql_db_schema to query the correct table fields.
#
# sql_db_schema: Input to this tool is a comma-separated list of tables, output is the schema and sample rows for those tables. Be sure that the tables actually exist by calling sql_db_list_tables first! Example Input: table1, table2, table3
#
# sql_db_list_tables: Input is an empty string, output is a comma-separated list of tables in the database.
#
# sql_db_query_checker: Use this tool to double check if your query is correct before executing it. Always use this tool before executing a query with sql_db_query!

# %% [markdown]
# ## 2. Using a prebuilt agent
#
# Given these tools, we can initialize a pre-built agent in a single line. To customize our agents behavior, we write a descriptive system prompt.

# %%
from langgraph.prebuilt import create_react_agent

system_prompt = """
You are an agent designed to interact with a SQL database.
Given an input question, create a syntactically correct {dialect} query to run,
then look at the results of the query and return the answer. Unless the user
specifies a specific number of examples they wish to obtain, always limit your
query to at most {top_k} results.

You can order the results by a relevant column to return the most interesting
examples in the database. Never query for all the columns from a specific table,
only ask for the relevant columns given the question.

You MUST double check your query before executing it. If you get an error while
executing a query, rewrite the query and try again.

DO NOT make any DML statements (INSERT, UPDATE, DELETE, DROP etc.) to the
database.

To start you should ALWAYS look at the tables in the database to see what you
can query. Do NOT skip this step.

Then you should query the schema of the most relevant tables.
""".format(
    dialect=db.dialect,
    top_k=5,
)

agent = create_react_agent(
    llm,
    tools,
    prompt=system_prompt,
)

# %% [markdown]
# Let's run this agent on a sample query and observe its behavior:

# %%
question = "What was the value of Coal ConsumptionKPI on date 4-1-24? for Boiler 1? "

for step in agent.stream(
    {"messages": [{"role": "user", "content": question}]},
    stream_mode="values",
):
    step["messages"][-1].pretty_print()
# Out:
# ================================ Human Message =================================
#
# What was the value of Coal ConsumptionKPI on date 4-1-24? for Boiler 1?
# ================================== Ai Message ==================================
# Tool Calls:
#   sql_db_list_tables (call_6GXoY9jK1sABXRhZQ9zq1GeL)
#  Call ID: call_6GXoY9jK1sABXRhZQ9zq1GeL
#   Args:
# ================================= Tool Message =================================
# Name: sql_db_list_tables
#
# boiler_bol2, boiler_bolr_1, boiler_bolr_3, boiler_data, monthly_stats, weekly_stats
# ================================== Ai Message ==================================
# Tool Calls:
#   sql_db_schema (call_4NYkULgfAA1GvTkW6utyNLS5)
#  Call ID: call_4NYkULgfAA1GvTkW6utyNLS5
#   Args:
#     table_names: boiler_bolr_1
# ================================= Tool Message =================================
# Name: sql_db_schema
#
#
# CREATE TABLE boiler_bolr_1 (
# 	"Date" DATETIME,
# 	"LDO Consumption(kl)" FLOAT,
# 	"Coal ConsumptionFeeder(MT)" BIGINT,
# 	"Coal ConsumptionKPI" FLOAT,
# 	"Difference Coal Feeder Vs KPI" FLOAT,
# 	"Equivalent Coal Consumption due to HFO Consumption" FLOAT,
# 	"Difference of Coal KPI to equivalent Coal KPI" FLOAT,
# 	"Bio fuel consumption(T)" FLOAT,
# 	"Coal ConsumptionBunkered(T)" BIGINT,
# 	"Actual Running Hours(HRS)" BIGINT,
# 	"Deemed Or Standby Running Hours(HRS)" BIGINT,
# 	"Breakdown Running Hours(HRS)" BIGINT,
# 	"No.of Tripping(Nos)" BIGINT,
# 	"No.of Stoppages(Nos)" BIGINT,
# 	"TM" FLOAT,
# 	"Oxygen (LHS)" FLOAT,
# 	"Oxygen (RHS)" FLOAT,
# 	"ESP Inlet (LHS)" FLOAT,
# 	"ESP Inlet (RHS)" FLOAT,
# 	"FD air inlet temperature" FLOAT,
# 	"Drum Pressure Avg. ( )" FLOAT,
# 	"Feed Water Temperature" FLOAT,
# 	"Feed Water Pressure" FLOAT,
# 	"Load" FLOAT,
# 	"APC" FLOAT,
# 	"FC" FLOAT,
# 	"VM" FLOAT,
# 	"Moisture" FLOAT,
# 	"Ash" FLOAT,
# 	"GCV" BIGINT,
# 	"C" FLOAT,
# 	"H2" FLOAT,
# 	"S" FLOAT,
# 	"N2" FLOAT,
# 	"O" FLOAT,
# 	"AVG O2 at APH I/L (Wet as measured)" FLOAT,
# 	"Leakage across APH" FLOAT,
# 	"Avg O2 at APH O/L" FLOAT,
# 	"PA Flow" FLOAT,
# 	"FD Flow" FLOAT,
# 	"Primary Air I/L temp to APH" FLOAT,
# 	"Secondary Air I/L temp to APH" FLOAT,
# 	"Weighted Air I/L temp to APH" FLOAT,
# 	"Flue Gas temp APH O/L" FLOAT,
# 	"CO2 APH O/L" FLOAT,
# 	"CO ESP outlet (Test)" BIGINT,
# 	"CO APH outlet (Test)" BIGINT,
# 	"CO Dilution across ESP (Test)" BIGINT,
# 	"CO Online ESP O/L" FLOAT,
# 	"CO APH O/L Measured" FLOAT,
# 	"CO APH O/L" FLOAT,
# 	"Bottom Ash Carbon" FLOAT,
# 	"ESP Ash Carbon" FLOAT,
# 	"Bottom Ash Temp  Unit specific" BIGINT,
# 	"Fly Ash Temp" FLOAT,
# 	"Hot Well makeup for 24 hours" FLOAT,
# 	"Hot well makeup  (% )" FLOAT,
# 	"Air Humidity Factor" FLOAT,
# 	"Theoretical Air" FLOAT,
# 	"Excess Air" FLOAT,
# 	"Actual Air Supplied" FLOAT,
# 	"Mass of Dry Flue Gas" FLOAT,
# 	"Loss Due to Dry Flue Gas" FLOAT,
# 	"Loss due to H2O in fuel" FLOAT,
# 	"Loss due to H2 in fuel" FLOAT,
# 	"Loss due to H2O in Air" FLOAT,
# 	"Partial Combustion Loss" FLOAT,
# 	"ESP Ash for Unburnt Loss" FLOAT,
# 	"Bottom Ash for Unburnt Loss" FLOAT,
# 	"Total Unburnt Loss" FLOAT,
# 	"ESP Ash for Sensible Heat Loss" FLOAT,
# 	"Bottom Ash for Sensible Heat Loss" FLOAT,
# 	"Total Sensisble Loss" FLOAT,
# 	"Radiation Loss" FLOAT,
# 	"Total Loss" FLOAT,
# 	"Boiler Efficiency (ASME PTC4)" FLOAT,
# 	"Mill reject loss" FLOAT,
# 	"Blow down leakage loss" FLOAT,
# 	"Other Losses  Plant Specific" FLOAT,
# 	"Boiler Efficiency" FLOAT,
# 	"Unit Generation" FLOAT,
# 	"Coal Feeder reading (DCS)" FLOAT,
# 	"Coal feed by CHP : Bunker Adjusted" BIGINT,
# 	"Coal feed by CHP: Beltweigher reading" BIGINT,
# 	"Running hours" FLOAT,
# 	"Derated Hours" FLOAT,
# 	"Steam generation from boiler" FLOAT,
# 	"Steam temp at boiler outlet" FLOAT,
# 	"Steam pressure at boiler outlet(kg/cm2)" FLOAT,
# 	"Steam pressure at boiler outlet(Bar)" FLOAT,
# 	"Steam enthalpy (Ref )" FLOAT,
# 	"Feed water flow" FLOAT,
# 	"FW temperature at ECO inlet" FLOAT,
# 	"FW pressure at ECO inlet (kg/cm2)" FLOAT,
# 	"FW pressure at ECO inlet(Bar)" FLOAT,
# 	"FW enthalpy (Ref)" FLOAT,
# 	"HSD/Bottom Oil Consumed(KL)" FLOAT,
# 	"Density of HSD/Bottom Oil" FLOAT,
# 	"HSD/Bottom Oil Consumed(MT)" FLOAT,
# 	"GCV of HSD/Bottom Oil" BIGINT,
# 	"Consump (w/o handling loss)" FLOAT,
# 	"Coal Consumption (with 0.8% handling loss)" FLOAT,
# 	"SOx (mg/m3)" FLOAT,
# 	"NOx (mg/m3)" FLOAT,
# 	"CO (PPM)" FLOAT,
# 	"Year" INTEGER,
# 	"Month" INTEGER,
# 	"Week" BIGINT,
# 	"Day" INTEGER,
# 	"DayOfWeek" INTEGER,
# 	"Sheet_Source" TEXT
# )
#
# /*
# 3 rows from boiler_bolr_1 table:
# Date	LDO Consumption(kl)	Coal ConsumptionFeeder(MT)	Coal ConsumptionKPI	Difference Coal Feeder Vs KPI	Equivalent Coal Consumption due to HFO Consumption	Difference of Coal KPI to equivalent Coal KPI	Bio fuel consumption(T)	Coal ConsumptionBunkered(T)	Actual Running Hours(HRS)	Deemed Or Standby Running Hours(HRS)	Breakdown Running Hours(HRS)	No.of Tripping(Nos)	No.of Stoppages(Nos)	TM	Oxygen (LHS)	Oxygen (RHS)	ESP Inlet (LHS)	ESP Inlet (RHS)	FD air inlet temperature	Drum Pressure Avg. ( )	Feed Water Temperature	Feed Water Pressure	Load	APC	FC	VM	Moisture	Ash	GCV	C	H2	S	N2	O	AVG O2 at APH I/L (Wet as measured)	Leakage across APH	Avg O2 at APH O/L	PA Flow	FD Flow	Primary Air I/L temp to APH	Secondary Air I/L temp to APH	Weighted Air I/L temp to APH	Flue Gas temp APH O/L	CO2 APH O/L	CO ESP outlet (Test)	CO APH outlet (Test)	CO Dilution across ESP (Test)	CO Online ESP O/L	CO APH O/L Measured	CO APH O/L	Bottom Ash Carbon	ESP Ash Carbon	Bottom Ash Temp  Unit specific	Fly Ash Temp	Hot Well makeup for 24 hours	Hot well makeup  (% )	Air Humidity Factor	Theoretical Air	Excess Air	Actual Air Supplied	Mass of Dry Flue Gas	Loss Due to Dry Flue Gas	Loss due to H2O in fuel	Loss due to H2 in fuel	Loss due to H2O in Air	Partial Combustion Loss	ESP Ash for Unburnt Loss	Bottom Ash for Unburnt Loss	Total Unburnt Loss	ESP Ash for Sensible Heat Loss	Bottom Ash for Sensible Heat Loss	Total Sensisble Loss	Radiation Loss	Total Loss	Boiler Efficiency (ASME PTC4)	Mill reject loss	Blow down leakage loss	Other Losses  Plant Specific	Boiler Efficiency	Unit Generation	Coal Feeder reading (
# 2024-04-03 00:00:00	0.0	1662	1356.0	306.0	0.18825301204819278	1355.811746987952	0.0	1214	24	0	0	0	0	10.38	2.7	2.1	128.3	121.2	0.0	84.87	155.8	101.05	26.09375	0.0	30.53	23.53	10.38	35.56	3984	42.43564716459999	3.0228988874000002	0.48654	1.8176400000000001	6.297273948000013	2.4000000000000004	17.8	5.872170686456401	192.487	247.2934	34.3801	27.9036	0.0	124.75	13.527829313543599	50	60	10	6.738	16.738	0.0016738	6.96	2.36	900	124.75	11.0	0.2065564781744914	0.0	5.7217369571707986	38.81700781221256	7.942744038830041	8.210625468049422	0.0	0.0	0.0	0.0	0.007569159341470121	1.4461836062248996	0.7526498927710844	2.198833498995984	0.14664572746987198	0.48509047540420325	0.6317362028740752	0.65	0.0	0.0	0.0	0.06426649567021736	0.5	84.85977361765345	541.125	1662.0	1214	1214	24.0	0.0	7089.0	492.8	75.16	74.68716902679166	810.5346728085071	7100.0	155.8	101.05	100.07649158592555	158.6258576203387	0.15	0.84	0.126	10750	0.0	0.0	1053.0	373.0	18.0	2024	4	14	3	2	Bolr 1
# */
# ================================== Ai Message ==================================
# Tool Calls:
#   sql_db_query_checker (call_xKp4h188im5gsnnDXZzol707)
#  Call ID: call_xKp4h188im5gsnnDXZzol707
#   Args:
#     query: SELECT "Date", "Coal ConsumptionKPI" FROM boiler_bolr_1 WHERE "Date" = '2024-04-01' LIMIT 1;
# ================================= Tool Message =================================
# Name: sql_db_query_checker
#
# SELECT "Date", "Coal ConsumptionKPI" FROM boiler_bolr_1 WHERE "Date" = '2024-04-01' LIMIT 1;
# ================================== Ai Message ==================================
# Tool Calls:
#   sql_db_query (call_CLY5kYTEpaSnpWrMUUxkxziM)
#  Call ID: call_CLY5kYTEpaSnpWrMUUxkxziM
#   Args:
#     query: SELECT "Date", "Coal ConsumptionKPI" FROM boiler_bolr_1 WHERE "Date" = '2024-04-01' LIMIT 1;
# ================================= Tool Message =================================
# Name: sql_db_query
#
#
# ================================== Ai Message ==================================
#
# The value of the Coal ConsumptionKPI on date 4-1-24 for Boiler 1 was 1300.63 (rounded to two decimals).

# %%
question = "What is the value of Difference of Coal KPI to equivalent Coal KPI at Coal ConsumptionKPI = 1296.01 for 3rd April 2024 for boiler ? "

for step in agent.stream(
    {"messages": [{"role": "user", "content": question}]},
    stream_mode="values",
):
    step["messages"][-1].pretty_print()
# Out:
# ================================ Human Message =================================
#
# What is the value of Difference of Coal KPI to equivalent Coal KPI at Coal ConsumptionKPI = 1296.01 for 3rd April 2024 for boiler ?
# ================================== Ai Message ==================================
# Tool Calls:
#   sql_db_list_tables (call_0UcEPi0unRDHYsVEMdlMicfi)
#  Call ID: call_0UcEPi0unRDHYsVEMdlMicfi
#   Args:
#     tool_input:
# ================================= Tool Message =================================
# Name: sql_db_list_tables
#
# boiler_bol2, boiler_bolr_1, boiler_bolr_3, boiler_data, monthly_stats, weekly_stats
# ================================== Ai Message ==================================
# Tool Calls:
#   sql_db_schema (call_LM8iPFsuS2iZiXXYjydQ8386)
#  Call ID: call_LM8iPFsuS2iZiXXYjydQ8386
#   Args:
#     table_names: boiler_data
# ================================= Tool Message =================================
# Name: sql_db_schema
#
#
# CREATE TABLE boiler_data (
# 	"Date" DATETIME,
# 	"LDO Consumption(kl)" FLOAT,
# 	"Coal ConsumptionFeeder(MT)" FLOAT,
# 	"Coal ConsumptionKPI" FLOAT,
# 	"Difference Coal Feeder Vs KPI" FLOAT,
# 	"Equivalent Coal Consumption due to HFO Consumption" FLOAT,
# 	"Difference of Coal KPI to equivalent Coal KPI" FLOAT,
# 	"Bio fuel consumption(T)" FLOAT,
# 	"Coal ConsumptionBunkered(T)" FLOAT,
# 	"Actual Running Hours(HRS)" FLOAT,
# 	"Deemed Or Standby Running Hours(HRS)" FLOAT,
# 	"Breakdown Running Hours(HRS)" FLOAT,
# 	"No.of Tripping(Nos)" FLOAT,
# 	"No.of Stoppages(Nos)" FLOAT,
# 	"TM" FLOAT,
# 	"Oxygen (LHS)" FLOAT,
# 	"Oxygen (RHS)" FLOAT,
# 	"ESP Inlet (LHS)" FLOAT,
# 	"ESP Inlet (RHS)" FLOAT,
# 	"FD air inlet temperature" FLOAT,
# 	"Drum Pressure Avg. ( )" FLOAT,
# 	"Feed Water Temperature" FLOAT,
# 	"Feed Water Pressure" FLOAT,
# 	"Load" FLOAT,
# 	"APC" FLOAT,
# 	"FC" FLOAT,
# 	"VM" FLOAT,
# 	"Moisture" FLOAT,
# 	"Ash" FLOAT,
# 	"GCV" FLOAT,
# 	"C" FLOAT,
# 	"H2" FLOAT,
# 	"S" FLOAT,
# 	"N2" FLOAT,
# 	"O" FLOAT,
# 	"AVG O2 at APH I/L (Wet as measured)" FLOAT,
# 	"Leakage across APH" FLOAT,
# 	"Avg O2 at APH O/L" FLOAT,
# 	"PA Flow" FLOAT,
# 	"FD Flow" FLOAT,
# 	"Primary Air I/L temp to APH" FLOAT,
# 	"Secondary Air I/L temp to APH" FLOAT,
# 	"Weighted Air I/L temp to APH" FLOAT,
# 	"Flue Gas temp APH O/L" FLOAT,
# 	"CO2 APH O/L" FLOAT,
# 	"CO ESP outlet (Test)" FLOAT,
# 	"CO APH outlet (Test)" FLOAT,
# 	"CO Dilution across ESP (Test)" FLOAT,
# 	"CO Online ESP O/L" FLOAT,
# 	"CO APH O/L Measured" FLOAT,
# 	"CO APH O/L" FLOAT,
# 	"Bottom Ash Carbon" FLOAT,
# 	"ESP Ash Carbon" FLOAT,
# 	"Bottom Ash Temp  Unit specific" FLOAT,
# 	"Fly Ash Temp" FLOAT,
# 	"Hot Well makeup for 24 hours" FLOAT,
# 	"Hot well makeup  (% )" FLOAT,
# 	"Air Humidity Factor" FLOAT,
# 	"Theoretical Air" FLOAT,
# 	"Excess Air" FLOAT,
# 	"Actual Air Supplied" FLOAT,
# 	"Mass of Dry Flue Gas" FLOAT,
# 	"Loss Due to Dry Flue Gas" FLOAT,
# 	"Loss due to H2O in fuel" FLOAT,
# 	"Loss due to H2 in fuel" FLOAT,
# 	"Loss due to H2O in Air" FLOAT,
# 	"Partial Combustion Loss" FLOAT,
# 	"ESP Ash for Unburnt Loss" FLOAT,
# 	"Bottom Ash for Unburnt Loss" FLOAT,
# 	"Total Unburnt Loss" FLOAT,
# 	"ESP Ash for Sensible Heat Loss" FLOAT,
# 	"Bottom Ash for Sensible Heat Loss" FLOAT,
# 	"Total Sensisble Loss" FLOAT,
# 	"Radiation Loss" FLOAT,
# 	"Total Loss" FLOAT,
# 	"Boiler Efficiency (ASME PTC4)" FLOAT,
# 	"Mill reject loss" FLOAT,
# 	"Blow down leakage loss" FLOAT,
# 	"Other Losses  Plant Specific" FLOAT,
# 	"Boiler Efficiency" FLOAT,
# 	"Unit Generation" FLOAT,
# 	"Coal Feeder reading (DCS)" FLOAT,
# 	"Coal feed by CHP : Bunker Adjusted" FLOAT,
# 	"Coal feed by CHP: Beltweigher reading" FLOAT,
# 	"Running hours" FLOAT,
# 	"Derated Hours" FLOAT,
# 	"Steam generation from boiler" FLOAT,
# 	"Steam temp at boiler outlet" FLOAT,
# 	"Steam pressure at boiler outlet(kg/cm2)" FLOAT,
# 	"Steam pressure at boiler outlet(Bar)" FLOAT,
# 	"Steam enthalpy (Ref )" FLOAT,
# 	"Feed water flow" FLOAT,
# 	"FW temperature at ECO inlet" FLOAT,
# 	"FW pressure at ECO inlet (kg/cm2)" FLOAT,
# 	"FW pressure at ECO inlet(Bar)" FLOAT,
# 	"FW enthalpy (Ref)" FLOAT,
# 	"HSD/Bottom Oil Consumed(KL)" FLOAT,
# 	"Density of HSD/Bottom Oil" FLOAT,
# 	"HSD/Bottom Oil Consumed(MT)" FLOAT,
# 	"GCV of HSD/Bottom Oil" FLOAT,
# 	"Consump (w/o handling loss)" FLOAT,
# 	"Coal Consumption (with 0.8% handling loss)" FLOAT,
# 	"SOx (mg/m3)" FLOAT,
# 	"NOx (mg/m3)" FLOAT,
# 	"CO (PPM)" FLOAT,
# 	"Year" INTEGER,
# 	"Month" INTEGER,
# 	"Week" BIGINT,
# 	"Day" INTEGER,
# 	"DayOfWeek" INTEGER,
# 	"Sheet_Source" TEXT
# )
#
# /*
# 3 rows from boiler_data table:
# Date	LDO Consumption(kl)	Coal ConsumptionFeeder(MT)	Coal ConsumptionKPI	Difference Coal Feeder Vs KPI	Equivalent Coal Consumption due to HFO Consumption	Difference of Coal KPI to equivalent Coal KPI	Bio fuel consumption(T)	Coal ConsumptionBunkered(T)	Actual Running Hours(HRS)	Deemed Or Standby Running Hours(HRS)	Breakdown Running Hours(HRS)	No.of Tripping(Nos)	No.of Stoppages(Nos)	TM	Oxygen (LHS)	Oxygen (RHS)	ESP Inlet (LHS)	ESP Inlet (RHS)	FD air inlet temperature	Drum Pressure Avg. ( )	Feed Water Temperature	Feed Water Pressure	Load	APC	FC	VM	Moisture	Ash	GCV	C	H2	S	N2	O	AVG O2 at APH I/L (Wet as measured)	Leakage across APH	Avg O2 at APH O/L	PA Flow	FD Flow	Primary Air I/L temp to APH	Secondary Air I/L temp to APH	Weighted Air I/L temp to APH	Flue Gas temp APH O/L	CO2 APH O/L	CO ESP outlet (Test)	CO APH outlet (Test)	CO Dilution across ESP (Test)	CO Online ESP O/L	CO APH O/L Measured	CO APH O/L	Bottom Ash Carbon	ESP Ash Carbon	Bottom Ash Temp  Unit specific	Fly Ash Temp	Hot Well makeup for 24 hours	Hot well makeup  (% )	Air Humidity Factor	Theoretical Air	Excess Air	Actual Air Supplied	Mass of Dry Flue Gas	Loss Due to Dry Flue Gas	Loss due to H2O in fuel	Loss due to H2 in fuel	Loss due to H2O in Air	Partial Combustion Loss	ESP Ash for Unburnt Loss	Bottom Ash for Unburnt Loss
3949312206922688	1.4971154164224356	0.1577716211543516	0.3901659068103499	0.5479375279647015	0.65	13.31585197767888	86.68414802232112	0.1340725406888094	0.217436696281781	0.5	86.2675121779141	541.125	1596.0	1266.0	1266.0	24.0	0.0	6876.0	491.5	75.03	74.55968305024909	809.8071543635419	6840.0	156.8	102.98	101.96916800690386	159.6811224571826	0.3	0.84	0.252	10750.0	1308.398349438155	1318.8655362336604	1057.0	367.0	14.0	2024	4	14	2	1	Bolr 1
# 2024-04-03 00:00:00	0.0	1662.0	1356.0	306.0	0.18825301204819278	1355.811746987952	0.0	1214.0	24.0	0.0	0.0	0.0	0.0	10.38	2.7	2.1	128.3	121.2	0.0	84.87	155.8	101.05	26.09375	0.0	30.53	23.53	10.38	35.56	3984.0	42.43564716459999	3.0228988874000002	0.48654	1.8176400000000001	6.297273948000013	2.4000000000000004	17.8	5.872170686456401	192.487	247.2934	34.3801	27.9036	0.0	124.75	13.527829313543599	50.0	60.0	10.0	6.738	16.738	0.0016738	6.96	2.36	900.0	124.75	11.0	0.2065564781744914	0.0	5.7217369571707986	38.81700781221256	7.942744038830041	8.210625468049422	0.0	0.0	0.0	0.0	0.007569159341470121	1.4461836062248996	0.7526498927710844	2.198833498995984	0.14664572746987198	0.48509047540420325	0.6317362028740752	0.65	0.0	0.0	0.0	0.06426649567021736	0.5	84.85977361765345	541.125	1662.0	1214.0	1214.0	24.0	0.0	7089.0	492.8	75.16	74.68716902679166	810.5346728085071	7100.0	155.8	101.05	100.07649158592555	158.6258576203387	0.15	0.84	0.126	10750.0	0.0	0.0	1053.0	373.0	18.0	2024	4	14	3	2	Bolr 1
# */
# ================================== Ai Message ==================================
# Tool Calls:
#   sql_db_query_checker (call_hreAYzwf0Cz02BFXI9FtfMHT)
#  Call ID: call_hreAYzwf0Cz02BFXI9FtfMHT
#   Args:
#     query: SELECT "Difference of Coal KPI to equivalent Coal KPI" FROM boiler_data WHERE DATE(Date) = '2024-04-03' AND "Coal ConsumptionKPI" = 1296.01 LIMIT 5;
# ================================= Tool Message =================================
# Name: sql_db_query_checker
#
# ```sql
# SELECT "Difference of Coal KPI to equivalent Coal KPI" FROM boiler_data WHERE DATE("Date") = '2024-04-03' AND "Coal ConsumptionKPI" = 1296.01 LIMIT 5;
# ```
# ================================== Ai Message ==================================
# Tool Calls:
#   sql_db_query (call_mk7qnkivFsgh9Clm0v0ApeIk)
#  Call ID: call_mk7qnkivFsgh9Clm0v0ApeIk
#   Args:
#     query: SELECT "Difference of Coal KPI to equivalent Coal KPI" FROM boiler_data WHERE DATE("Date") = '2024-04-03' AND "Coal ConsumptionKPI" = 1296.01 LIMIT 5;
# ================================= Tool Message =================================
# Name: sql_db_query
#
#
# ================================== Ai Message ==================================
#
# There is no entry for Coal ConsumptionKPI = 1296.01 on 3rd April 2024 for the boiler. Therefore, the value for the "Difference of Coal KPI to equivalent Coal KPI" at those exact criteria is not available in the database. If you would like, I can provide the value for the available Coal ConsumptionKPI on that date.

# %%
question = "who is the richest person in the world?"

for step in agent.stream(
    {"messages": [{"role": "user", "content": question}]},
    stream_mode="values",
):
    step["messages"][-1].pretty_print()
# Out:
# ================================ Human Message =================================
#
# who is the richest person in the world?
# ================================== Ai Message ==================================
# Tool Calls:
#   sql_db_list_tables (call_EnI9EGpGZCWmByGHTszFbYUc)
#  Call ID: call_EnI9EGpGZCWmByGHTszFbYUc
#   Args:
# ================================= Tool Message =================================
# Name: sql_db_list_tables
#
# boiler_bol2, boiler_bolr_1, boiler_bolr_3, boiler_data, monthly_stats, weekly_stats
# ================================== Ai Message ==================================
#
# It appears that the database available does not contain information about the wealth or net worth of people in the world. If you have another database or specific dataset related to this topic, please provide more information or clarify your request!

# %%
question = "What is the value of CO2 APH O/L for Flue Gas temp APH O/L = 123.35 and Weighted Air I/L temp to APH = 33.2 for 1st April 2024 for boiler 2"

for step in agent.stream(
    {"messages": [{"role": "user", "content": question}]},
    stream_mode="values",
):
    step["messages"][-1].pretty_print()
# Out:
# ================================ Human Message =================================
#
# What is the value of CO2 APH O/L for Flue Gas temp APH O/L = 123.35 and Weighted Air I/L temp to APH = 33.2 for 1st April 2024 for boiler 2
# ================================== Ai Message ==================================
# Tool Calls:
#   sql_db_list_tables (call_s47dfnWztOhaDxXJuEPQODjp)
#  Call ID: call_s47dfnWztOhaDxXJuEPQODjp
#   Args:
# ================================= Tool Message =================================
# Name: sql_db_list_tables
#
# boiler_bol2, boiler_bolr_1, boiler_bolr_3, boiler_data, monthly_stats, weekly_stats
# ================================== Ai Message ==================================
# Tool Calls:
#   sql_db_schema (call_6KNspv813hkgXPTrzqg81lcT)
#  Call ID: call_6KNspv813hkgXPTrzqg81lcT
#   Args:
#     table_names: boiler_bol2, boiler_data
# ================================= Tool Message =================================
# Name: sql_db_schema
#
#
# CREATE TABLE boiler_bol2 (
# 	"Date" DATETIME,
# 	"LDO Consumption(kl)" FLOAT,
# 	"Coal ConsumptionFeeder(MT)" FLOAT,
# 	"Coal ConsumptionKPI" FLOAT,
# 	"Difference Coal Feeder Vs KPI" FLOAT,
# 	"Equivalent Coal Consumption due to HFO Consumption" FLOAT,
# 	"Difference of Coal KPI to equivalent Coal KPI" FLOAT,
# 	"Bio fuel consumption(T)" FLOAT,
# 	"Coal ConsumptionBunkered(T)" FLOAT,
# 	"Actual Running Hours(HRS)" FLOAT,
# 	"Deemed Or Standby Running Hours(HRS)" FLOAT,
# 	"Breakdown Running Hours(HRS)" FLOAT,
# 	"No.of Tripping(Nos)" FLOAT,
# 	"No.of Stoppages(Nos)" FLOAT,
# 	"TM" FLOAT,
# 	"Oxygen (LHS)" FLOAT,
# 	"Oxygen (RHS)" FLOAT,
# 	"ESP Inlet (LHS)" FLOAT,
# 	"ESP Inlet (RHS)" FLOAT,
# 	"FD air inlet temperature" FLOAT,
# 	"Drum Pressure Avg. ( )" FLOAT,
# 	"Feed Water Temperature" FLOAT,
# 	"Feed Water Pressure" FLOAT,
# 	"Load" FLOAT,
# 	"APC" FLOAT,
# 	"FC" FLOAT,
# 	"VM" FLOAT,
# 	"Moisture" FLOAT,
# 	"Ash" FLOAT,
# 	"GCV" FLOAT,
# 	"C" FLOAT,
# 	"H2" FLOAT,
# 	"S" FLOAT,
# 	"N2" FLOAT,
# 	"O" FLOAT,
# 	"AVG O2 at APH I/L (Wet as measured)" FLOAT,
# 	"Leakage across APH" FLOAT,
# 	"Avg O2 at APH O/L" FLOAT,
# 	"PA Flow" FLOAT,
# 	"FD Flow" FLOAT,
# 	"Primary Air I/L temp to APH" FLOAT,
# 	"Secondary Air I/L temp to APH" FLOAT,
# 	"Weighted Air I/L temp to APH" FLOAT,
# 	"Flue Gas temp APH O/L" FLOAT,
# 	"CO2 APH O/L" FLOAT,
# 	"CO ESP outlet (Test)" FLOAT,
# 	"CO APH outlet (Test)" FLOAT,
# 	"CO Dilution across ESP (Test)" FLOAT,
# 	"CO Online ESP O/L" FLOAT,
# 	"CO APH O/L Measured" FLOAT,
# 	"CO APH O/L" FLOAT,
# 	"Bottom Ash Carbon" FLOAT,
# 	"ESP Ash Carbon" FLOAT,
# 	"Bottom Ash Temp  Unit specific" FLOAT,
# 	"Fly Ash Temp" FLOAT,
# 	"Hot Well makeup for 24 hours" FLOAT,
# 	"Hot well makeup  (% )" FLOAT,
# 	"Air Humidity Factor" FLOAT,
# 	"Theoretical Air" FLOAT,
# 	"Excess Air" FLOAT,
# 	"Actual Air Supplied" FLOAT,
# 	"Mass of Dry Flue Gas" FLOAT,
# 	"Loss Due to Dry Flue Gas" FLOAT,
# 	"Loss due to H2O in fuel" FLOAT,
# 	"Loss due to H2 in fuel" FLOAT,
# 	"Loss due to H2O in Air" FLOAT,
# 	"Partial Combustion Loss" FLOAT,
# 	"ESP Ash for Unburnt Loss" FLOAT,
# 	"Bottom Ash for Unburnt Loss" FLOAT,
# 	"Total Unburnt Loss" FLOAT,
# 	"ESP Ash for Sensible Heat Loss" FLOAT,
# 	"Bottom Ash for Sensible Heat Loss" FLOAT,
# 	"Total Sensisble Loss" FLOAT,
# 	"Radiation Loss" FLOAT,
# 	"Total Loss" FLOAT,
# 	"Boiler Efficiency (ASME PTC4)" FLOAT,
# 	"Mill reject loss" FLOAT,
# 	"Blow down leakage loss" FLOAT,
# 	"Other Losses  Plant Specific" FLOAT,
# 	"Boiler Efficiency" FLOAT,
# 	"Unit Generation" FLOAT,
# 	"Coal Feeder reading (DCS)" FLOAT,
# 	"Coal feed by CHP : Bunker Adjusted" FLOAT,
# 	"Coal feed by CHP: Beltweigher reading" FLOAT,
# 	"Running hours" FLOAT,
# 	"Derated Hours" FLOAT,
# 	"Steam generation from boiler" FLOAT,
# 	"Steam temp at boiler outlet" FLOAT,
# 	"Steam pressure at boiler outlet(kg/cm2)" FLOAT,
# 	"Steam pressure at boiler outlet(Bar)" FLOAT,
# 	"Steam enthalpy (Ref )" FLOAT,
# 	"Feed water flow" FLOAT,
# 	"FW temperature at ECO inlet" FLOAT,
# 	"FW pressure at ECO inlet (kg/cm2)" FLOAT,
# 	"FW pressure at ECO inlet(Bar)" FLOAT,
# 	"FW enthalpy (Ref)" FLOAT,
# 	"HSD/Bottom Oil Consumed(KL)" FLOAT,
# 	"Density of HSD/Bottom Oil" FLOAT,
# 	"HSD/Bottom Oil Consumed(MT)" FLOAT,
# 	"GCV of HSD/Bottom Oil" FLOAT,
# 	"Consump (w/o handling loss)" FLOAT,
# 	"Coal Consumption (with 0.8% handling loss)" FLOAT,
# 	"SOx (mg/m3)" FLOAT,
# 	"NOx (mg/m3)" FLOAT,
# 	"CO (PPM)" FLOAT,
# 	"Year" INTEGER,
# 	"Month" INTEGER,
# 	"Week" BIGINT,
# 	"Day" INTEGER,
# 	"DayOfWeek" INTEGER,
# 	"Sheet_Source" TEXT
# )
#
# /*
# 3 rows from boiler_bol2 table:
# Date	LDO Consumption(kl)	Coal ConsumptionFeeder(MT)	Coal ConsumptionKPI	Difference Coal Feeder Vs KPI	Equivalent Coal Consumption due to HFO Consumption	Difference of Coal KPI to equivalent Coal KPI	Bio fuel consumption(T)	Coal ConsumptionBunkered(T)	Actual Running Hours(HRS)	Deemed Or Standby Running Hours(HRS)	Breakdown Running Hours(HRS)	No.of Tripping(Nos)	No.of Stoppages(Nos)	TM	Oxygen (LHS)	Oxygen (RHS)	ESP Inlet (LHS)	ESP Inlet (RHS)	FD air inlet temperature	Drum Pressure Avg. ( )	Feed Water Temperature	Feed Water Pressure	Load	APC	FC	VM	Moisture	Ash	GCV	C	H2	S	N2	O	AVG O2 at APH I/L (Wet as measured)	Leakage across APH	Avg O2 at APH O/L	PA Flow	FD Flow	Primary Air I/L temp to APH	Secondary Air I/L temp to APH	Weighted Air I/L temp to APH	Flue Gas temp APH O/L	CO2 APH O/L	CO ESP outlet (Test)	CO APH outlet (Test)	CO Dilution across ESP (Test)	CO Online ESP O/L	CO APH O/L Measured	CO APH O/L	Bottom Ash Carbon	ESP Ash Carbon	Bottom Ash Temp  Unit specific	Fly Ash Temp	Hot Well makeup for 24 hours	Hot well makeup  (% )	Air Humidity Factor	Theoretical Air	Excess Air	Actual Air Supplied	Mass of Dry Flue Gas	Loss Due to Dry Flue Gas	Loss due to H2O in fuel	Loss due to H2 in fuel	Loss due to H2O in Air	Partial Combustion Loss	ESP Ash for Unburnt Loss	Bottom Ash for Unburnt Loss	Total Unburnt Loss	ESP Ash for Sensible Heat Loss	Bottom Ash for Sensible Heat Loss	Total Sensisble Loss	Radiation Loss	Total Loss	Boiler Efficiency (ASME PTC4)	Mill reject loss	Blow down leakage loss	Other Losses  Plant Specific	Boiler Efficiency	Unit Generation	Coal Feeder reading (DCS)	Coal feed by CHP : Bunker Adjusted	Coal feed by CHP: Beltweigher reading	Running hours	Derated Hours	Steam generation from boiler	Steam temp at boiler outlet	Steam pressure at boiler outlet(kg/cm2)	Steam pressure at boiler outlet(Bar)	Steam enthalpy (Ref )	Feed water flow	FW temperature at ECO inlet	FW pressure at ECO inlet (kg/cm2)	FW pressure at ECO inlet(Bar)	FW enthalpy (Ref)	HSD/Bottom Oil Consumed(KL)	Density of HSD/Bottom Oil	HSD/Bottom Oil Consumed(MT)	GCV of HSD/Bottom Oil	Consump (w/o handling loss)	Coal Consumption (with 0.8% handling loss)	SOx (mg/m3)	NOx (mg/m3)	CO (PPM)	Year	Month	Week	Day	DayOfWeek	Sheet_Source
# 2024-04-01 00:00:00	0.0	1479.0	1329.2243023413428	149.77569765865724	0.0	1329.2243023413428	0.0	923.0	24.0	0.0	0.0	0.0	0.0	10.29	2.0	2.5	122.4	124.3	29.2	83.96	155.0	101.8	27.833333333333332	6.779	29.980000000000004	23.5	10.29	36.23	3942.0	41.9721091108	3.0122432232	0.48132	1.818	6.196327666000009	2.25	17.69	5.7314606741573035	192.487	247.2934	34.3801	27.9036	33.2	123.35	13.668539325842694	50.0	60.0	10.0	6.738	16.738	0.0016738	7.45	2.88	900.0	123.35	60.0	1.1173558890242132	0.022108138699871965	5.6684224650554	37.53771432776511	7.796218696878757	8.059265263978682	4.423395820686015	1.630339821156773	4.265250627330649	0.17737720968384163	0.007488362892045017	1.8172438611872144	0.8295629145738
# 	"Difference of Coal KPI to equivalent Coal KPI" FLOAT,
# 	"Bio fuel consumption(T)" FLOAT,
# 	"Coal ConsumptionBunkered(T)" FLOAT,
# 	"Actual Running Hours(HRS)" FLOAT,
# 	"Deemed Or Standby Running Hours(HRS)" FLOAT,
# 	"Breakdown Running Hours(HRS)" FLOAT,
# 	"No.of Tripping(Nos)" FLOAT,
# 	"No.of Stoppages(Nos)" FLOAT,
# 	"TM" FLOAT,
# 	"Oxygen (LHS)" FLOAT,
# 	"Oxygen (RHS)" FLOAT,
# 	"ESP Inlet (LHS)" FLOAT,
# 	"ESP Inlet (RHS)" FLOAT,
# 	"FD air inlet temperature" FLOAT,
# 	"Drum Pressure Avg. ( )" FLOAT,
# 	"Feed Water Temperature" FLOAT,
# 	"Feed Water Pressure" FLOAT,
# 	"Load" FLOAT,
# 	"APC" FLOAT,
# 	"FC" FLOAT,
# 	"VM" FLOAT,
# 	"Moisture" FLOAT,
# 	"Ash" FLOAT,
# 	"GCV" FLOAT,
# 	"C" FLOAT,
# 	"H2" FLOAT,
# 	"S" FLOAT,
# 	"N2" FLOAT,
# 	"O" FLOAT,
# 	"AVG O2 at APH I/L (Wet as measured)" FLOAT,
# 	"Leakage across APH" FLOAT,
# 	"Avg O2 at APH O/L" FLOAT,
# 	"PA Flow" FLOAT,
# 	"FD Flow" FLOAT,
# 	"Primary Air I/L temp to APH" FLOAT,
# 	"Secondary Air I/L temp to APH" FLOAT,
# 	"Weighted Air I/L temp to APH" FLOAT,
# 	"Flue Gas temp APH O/L" FLOAT,
# 	"CO2 APH O/L" FLOAT,
# 	"CO ESP outlet (Test)" FLOAT,
# 	"CO APH outlet (Test)" FLOAT,
# 	"CO Dilution across ESP (Test)" FLOAT,
# 	"CO Online ESP O/L" FLOAT,
# 	"CO APH O/L Measured" FLOAT,
# 	"CO APH O/L" FLOAT,
# 	"Bottom Ash Carbon" FLOAT,
# 	"ESP Ash Carbon" FLOAT,
# 	"Bottom Ash Temp  Unit specific" FLOAT,
# 	"Fly Ash Temp" FLOAT,
# 	"Hot Well makeup for 24 hours" FLOAT,
# 	"Hot well makeup  (% )" FLOAT,
# 	"Air Humidity Factor" FLOAT,
# 	"Theoretical Air" FLOAT,
# 	"Excess Air" FLOAT,
# 	"Actual Air Supplied" FLOAT,
# 	"Mass of Dry Flue Gas" FLOAT,
# 	"Loss Due to Dry Flue Gas" FLOAT,
# 	"Loss due to H2O in fuel" FLOAT,
# 	"Loss due to H2 in fuel" FLOAT,
# 	"Loss due to H2O in Air" FLOAT,
# 	"Partial Combustion Loss" FLOAT,
# 	"ESP Ash for Unburnt Loss" FLOAT,
# 	"Bottom Ash for Unburnt Loss" FLOAT,
# 	"Total Unburnt Loss" FLOAT,
# 	"ESP Ash for Sensible Heat Loss" FLOAT,
# 	"Bottom Ash for Sensible Heat Loss" FLOAT,
# 	"Total Sensisble Loss" FLOAT,
# 	"Radiation Loss" FLOAT,
# 	"Total Loss" FLOAT,
# 	"Boiler Efficiency (ASME PTC4)" FLOAT,
# 	"Mill reject loss" FLOAT,
# 	"Blow down leakage loss" FLOAT,
# 	"Other Losses  Plant Specific" FLOAT,
# 	"Boiler Efficiency" FLOAT,
# 	"Unit Generation" FLOAT,
# 	"Coal Feeder reading (DCS)" FLOAT,
# 	"Coal feed by CHP : Bunker Adjusted" FLOAT,
# 	"Coal feed by CHP: Beltweigher reading" FLOAT,
# 	"Running hours" FLOAT,
# 	"Derated Hours" FLOAT,
# 	"Steam generation from boiler" FLOAT,
# 	"Steam temp at boiler outlet" FLOAT,
# 	"Steam pressure at boiler outlet(kg/cm2)" FLOAT,
# 	"Steam pressure at boiler outlet(Bar)" FLOAT,
# 	"Steam enthalpy (Ref )" FLOAT,
# 	"Feed water flow" FLOAT,
# 	"FW temperature at ECO inlet" FLOAT,
# 	"FW pressure at ECO inlet (kg/cm2)" FLOAT,
# 	"FW pressure at ECO inlet(Bar)" FLOAT,
# 	"FW enthalpy (Ref)" FLOAT,
# 	"HSD/Bottom Oil Consumed(KL)" FLOAT,
# 	"Density of HSD/Bottom Oil" FLOAT,
# 	"HSD/Bottom Oil Consumed(MT)" FLOAT,
# 	"GCV of HSD/Bottom Oil" FLOAT,
# 	"Consump (w/o handling loss)" FLOAT,
# 	"Coal Consumption (with 0.8% handling loss)" FLOAT,
# 	"SOx (mg/m3)" FLOAT,
# 	"NOx (mg/m3)" FLOAT,
# 	"CO (PPM)" FLOAT,
# 	"Year" INTEGER,
# 	"Month" INTEGER,
# 	"Week" BIGINT,
# 	"Day" INTEGER,
# 	"DayOfWeek" INTEGER,
# 	"Sheet_Source" TEXT
# )
#
# /*
# 3 rows from boiler_data table:
# Date	LDO Consumption(kl)	Coal ConsumptionFeeder(MT)	Coal ConsumptionKPI	Difference Coal Feeder Vs KPI	Equivalent Coal Consumption due to HFO Consumption	Difference of Coal KPI to equivalent Coal KPI	Bio fuel consumption(T)	Coal ConsumptionBunkered(T)	Actual Running Hours(HRS)	Deemed Or Standby Running Hours(HRS)	Breakdown Running Hours(HRS)	No.of Tripping(Nos)	No.of Stoppages(Nos)	TM	Oxygen (LHS)	Oxygen (RHS)	ESP Inlet (LHS)	ESP Inlet (RHS)	FD air inlet temperature	Drum Pressure Avg. ( )	Feed Water Temperature	Feed Water Pressure	Load	APC	FC	VM	Moisture	Ash	GCV	C	H2	S	N2	O	AVG O2 at APH I/L (Wet as measured)	Leakage across APH	Avg O2 at APH O/L	PA Flow	FD Flow	Primary Air I/L temp to APH	Secondary Air I/L temp to APH	Weighted Air I/L temp to APH	Flue Gas temp APH O/L	CO2 APH O/L	CO ESP outlet (Test)	CO APH outlet (Test)	CO Dilution across ESP (Test)	CO Online ESP O/L	CO APH O/L Measured	CO APH O/L	Bottom Ash Carbon	ESP Ash Carbon	Bottom Ash Temp  Unit specific	Fly Ash Temp	Hot Well makeup for 24 hours	Hot well makeup  (% )	Air Humidity Factor	Theoretical Air	Excess Air	Actual Air Supplied	Mass of Dry Flue Gas	Loss Due to Dry Flue Gas	Loss due to H2O in fuel	Loss due to H2 in fuel	Loss due to H2O in Air	Partial Combustion Loss	
686686	0.19934920282803342	0.00757927810314562	1.1021841957301668	0.3949312206922688	1.4971154164224356	0.1577716211543516	0.3901659068103499	0.5479375279647015	0.65	13.31585197767888	86.68414802232112	0.1340725406888094	0.217436696281781	0.5	86.2675121779141	541.125	1596.0	1266.0	1266.0	24.0	0.0	6876.0	491.5	75.03	74.55968305024909	809.8071543635419	6840.0	156.8	102.98	101.96916800690386	159.6811224571826	0.3	0.84	0.252	10750.0	1308.398349438155	1318.8655362336604	1057.0	367.0	14.0	2024	4	14	2	1	Bolr 1
# 2024-04-03 00:00:00	0.0	1662.0	1356.0	306.0	0.18825301204819278	1355.811746987952	0.0	1214.0	24.0	0.0	0.0	0.0	0.0	10.38	2.7	2.1	128.3	121.2	0.0	84.87	155.8	101.05	26.09375	0.0	30.53	23.53	10.38	35.56	3984.0	42.43564716459999	3.0228988874000002	0.48654	1.8176400000000001	6.297273948000013	2.4000000000000004	17.8	5.872170686456401	192.487	247.2934	34.3801	27.9036	0.0	124.75	13.527829313543599	50.0	60.0	10.0	6.738	16.738	0.0016738	6.96	2.36	900.0	124.75	11.0	0.2065564781744914	0.0	5.7217369571707986	38.81700781221256	7.942744038830041	8.210625468049422	0.0	0.0	0.0	0.0	0.007569159341470121	1.4461836062248996	0.7526498927710844	2.198833498995984	0.14664572746987198	0.48509047540420325	0.6317362028740752	0.65	0.0	0.0	0.0	0.06426649567021736	0.5	84.85977361765345	541.125	1662.0	1214.0	1214.0	24.0	0.0	7089.0	492.8	75.16	74.68716902679166	810.5346728085071	7100.0	155.8	101.05	100.07649158592555	158.6258576203387	0.15	0.84	0.126	10750.0	0.0	0.0	1053.0	373.0	18.0	2024	4	14	3	2	Bolr 1
# */
# ================================== Ai Message ==================================
# Tool Calls:
#   sql_db_query_checker (call_vuFOl2CUki43Q0J0IBpxIPBw)
#  Call ID: call_vuFOl2CUki43Q0J0IBpxIPBw
#   Args:
#     query: SELECT "CO2 APH O/L" FROM boiler_bol2 WHERE Date = '2024-04-01' AND ROUND("Flue Gas temp APH O/L", 2) = 123.35 AND ROUND("Weighted Air I/L temp to APH", 1) = 33.2 LIMIT 1;
# ================================= Tool Message =================================
# Name: sql_db_query_checker
#
# ```sql
# SELECT "CO2 APH O/L" FROM boiler_bol2 WHERE Date = '2024-04-01' AND ROUND("Flue Gas temp APH O/L", 2) = 123.35 AND ROUND("Weighted Air I/L temp to APH", 1) = 33.2 LIMIT 1;
# ```
# ================================== Ai Message ==================================
# Tool Calls:
#   sql_db_query (call_y2VSHucdKXzX533ovvTmoWHa)
#  Call ID: call_y2VSHucdKXzX533ovvTmoWHa
#   Args:
#     query: SELECT "CO2 APH O/L" FROM boiler_bol2 WHERE Date = '2024-04-01' AND ROUND("Flue Gas temp APH O/L", 2) = 123.35 AND ROUND("Weighted Air I/L temp to APH", 1) = 33.2 LIMIT 1;
# ================================= Tool Message =================================
# Name: sql_db_query
#
#
# ================================== Ai Message ==================================
#
# The value of "CO2 APH O/L" for Flue Gas temp APH O/L = 123.35 and Weighted Air I/L temp to APH = 33.2 on 1st April 2024 for boiler 2 is 13.6685.

# %% [markdown]
# LangGraph also comes with built-in utilities for visualizing the control flow of your application

# %%
question = " "

for step in agent.stream(
    {"messages": [{"role": "user", "content": question}]},
    stream_mode="values",
):
    step["messages"][-1].pretty_print()
